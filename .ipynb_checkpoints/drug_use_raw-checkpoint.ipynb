# %% [markdown]
# Questions:
# 1. Which age group use the most drugs of any group?

# %%
from IPython.core.debugger import Tracer; 
import pandas as pd
import numpy as np
import math
% matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('bmh')
import seaborn as sns
import scipy.stats  as stats

#https://github.com/fivethirtyeight/data/blob/master/drug-use-by-age/drug-use-by-age.csv
#key structure: [drug]-[x] where x is in {use, frequency}

drug_use_by_age_df = pd.read_csv('data/drug-use-by-age.csv', index_col=0).replace('-', np.nan)

'''For each column, we find the row (the age group) which takes the max value for that column.
For example, max_age_group_dict['alcohol-use'] = 22-23.'''

max_age_group_dict = {}
drug_use_by_age_df.head(10)
for key in list(drug_use_by_age_df): 
    max_age_group_dict[key] = drug_use_by_age_df[key].dropna().argmax()
# fig, ax = plt.subplots()
drug_use_by_age_df.head(50)

'''Define the barchart function'''
def plot_marriagerate_over_time(keys, labels, title, flip_values): 
    fig = plt.figure(figsize=[18, 12])
    ax = plt.subplot()
    for i in range(len(keys)): #will this compile? 
        if (flip_values): 
            ax.plot(years_tracked, 1 - drug_use_by_age_df[keys[i]], label=labels[i])
        else:
            ax.plot(years_tracked, drug_use_by_age_df[keys[i]], label=labels[i])
    ax.set_title(title, fontsize=50)
    ax.set_ylim(0, 1)
    ax.set_xlabel('Year', fontsize=40)
    ax.set_ylabel('Marriage Rate', fontsize=40)
    ax.tick_params(labelsize=30)
    ax.legend(fontsize=30)
    fig.show()
# Out:
#           n  alcohol-use  alcohol-frequency  marijuana-use  \
# age
# 12     2798          3.9                3.0            1.1
# 13     2757          8.5                6.0            3.4
# 14     2792         18.1                5.0            8.7
# 15     2956         29.2                6.0           14.5
# 16     3058         40.1               10.0           22.5
# 17     3038         49.3               13.0           28.0
# 18     2469         58.7               24.0           33.7
# 19     2223         64.6               36.0           33.4
# 20     2271         69.7               48.0           34.0
# 21     2354         83.2               52.0           33.0
# 22-23  4707         84.2               52.0           28.4
# 24-25  4591         83.1               52.0           24.9
# 26-29  2628         80.7               52.0           20.8
# 30-34  2864         77.5               52.0           16.4
# 35-49  7391         75.0               52.0           10.4
# ...

# %%
# USE
'''Goal here is to have a bar chart whose x axis is age group, y-axis is percentage, and compares different drugs'''
np.arange(5)
# Out:
# array([0, 1, 2, 3, 4])

# %%
# FREQUENCY
